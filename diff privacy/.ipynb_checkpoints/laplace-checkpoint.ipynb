# %%
import pandas as pd
import numpy as np
from scipy.stats import laplace
import matplotlib.pyplot as plt

df_adult = pd.read_csv("adult.csv")
df_adult.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0    2         State-gov   77516  Bachelors             13
# 1    3  Self-emp-not-inc   83311  Bachelors             13
# 2    2           Private  215646    HS-grad              9
# 3    3           Private  234721       11th              7
# 4    1           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capitalgain  capitalloss  hoursperweek native-country  class
# 0            1            0             2  United-States  <=50K
# ...

# %%
def plota(scale, a, b):
    dist = laplace(0, scale)
    x = np.linspace(-100, 100,1000)
    plt.plot(x, dist.pdf(x), c='black')
    plt.show()

# %%
def consulta1(eplison):
    if(eplison == 0): return np.mean(df_adult['age'].values)
    plota(np.max(df_adult['age'].values)/eplison, -100, 100)
    return np.mean(df_adult['age'].values) + laplace.rvs(loc = 0, scale = np.max(df_adult['age'].values)/eplison)

# %%
def consulta2(eplison):
    if(eplison == 0): return np.sum(df_adult['capitalgain'].values)
    plota(np.max(df_adult['capitalgain'].values)/eplison, -100,100)
    return np.sum(df_adult['capitalgain'].values) + laplace.rvs(loc = 0, scale = np.max(df_adult['capitalgain'].values)/eplison)

# %%
def consulta3(eplison):
    if(eplison == 0): return np.mean(df_adult['hoursperweek'].values)
    plota(np.max(df_adult['hoursperweek'].values)/eplison, -20, 20)
    return np.mean(df_adult['hoursperweek'].values) + laplace.rvs(loc = 0, scale = np.max(df_adult['hoursperweek'].values)/eplison)

# %%
def consulta4(eplison):
    df_copy = df_adult.copy()
    df_copy = df_copy.replace('>50K', 1)
    df_copy = df_copy.replace('<=50K', 0)
    df_copy['class'] = df_copy['class'].astype(int)
    if(eplison == 0): return np.sum(df_copy['class'].values)
    plota(1/eplison, -20,20)
    return np.sum(df_copy['class'].values) + laplace.rvs(loc = 0, scale = 1/eplison)

# %%
def consultar():
    for eplison in [0,0.1,1,10]:
        print("consulta 1 (e=" + str(eplison/4) + "): " + str(consulta1(eplison/4)))
        
    print("\n")
    for eplison in [0,0.1,1,10]:
        print("consulta 2 (e=" + str(eplison/4) + "): " + str(consulta2(eplison/4)))

    print("\n")
    for eplison in [0,0.1,1,10]:
        print("consulta 3 (e=" + str(eplison/4) + "): " + str(consulta3(eplison/4)))
    
    print("\n")
    for eplison in [0,0.1,1,10]:
        print("consulta 4 (e=" + str(eplison/4) + "): " + str(consulta4(eplison/4)))
    
    print("\n")

# %%
consultar()
# Out:
# consulta 1 (e=0.0): 1.7710781704270915
# consulta 1 (e=0.025): -72.53633063129091
# consulta 1 (e=0.25): 35.49834846731202
# consulta 1 (e=2.5): 2.690089052220068
#
#
# consulta 2 (e=0.0): 9784
# consulta 2 (e=0.025): 9927.424197762668
# consulta 2 (e=0.25): 9772.994884631056
# consulta 2 (e=2.5): 9786.238689441656
#
#
# consulta 3 (e=0.0): 1.9506981696081243
# consulta 3 (e=0.025): 33.4855541544131
# consulta 3 (e=0.25): 2.34733695335061
# consulta 3 (e=2.5): 5.988529856599081
#
#
# consulta 4 (e=0.0): 11687
# consulta 4 (e=0.025): 11655.412314609224
# consulta 4 (e=0.25): 11687.154262472357
# consulta 4 (e=2.5): 11686.544257255748
